# %% [markdown]
# # Some examples of  simple Lagrangian mechanics problems
#
# Taken from [http://www.dzre.com/alex/P441/lectures/lec_18.pdf](http://www.dzre.com/alex/P441/lectures/lec_18.pdf)

# %%
import lagrangian
import sympy

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def Example_1(x1, x2, dx1, dx2):
    M = sympy.Symbol('M')
    m = sympy.Symbol('m')
    g = sympy.Symbol('g')
    theta = sympy.Symbol(r'\theta')
    half = sympy.Rational(1, 2)
    T = half*M*dx1**2 + half*m*(dx1**2 + dx2**2 + 2*dx1*dx2*sympy.cos(theta))
    U = -m*g*x2*sympy.sin(theta)
    return T-U

solver1 = lagrangian.solver(n=2, lagrangian=Example_1, custom_coords=[r'x_{1}', r'x_{2}'])
equations1 = solver1.euler_lagrange_equations()
accelarations = solver1.get_second_derivatives()
p_eqs1, q_eqs1 = solver1.hamitonian_equations()

solver1.print_lagrangian()
print('Euler-Lagrange equations:')
for i in range(len(equations1)):
    print(f'Coordinate {i}:')
    lagrangian.pprint(equations1[i])
print('Accelerations:')
for i in range(len(accelarations)):
    print(f'Coordinate {i}:')
    lagrangian.pprint(accelarations[i])

print('\n')

solver1.print_hamiltonian()
print('Hamiltonian equations:')
for i in range(len(p_eqs1)):
    print(f'Coordinate {i}:')
    lagrangian.pprint(p_eqs1[i] + ',~~~~' + q_eqs1[i])
# Out:
# Lagrangian for Example 1:
# $\displaystyle \mathcal{L} = \frac{M \dot{ x_{1}}^{2}}{2} + g m x_{2} \sin{\left(\theta \right)} + \frac{m \left(\dot{ x_{1}}^{2} + 2 \dot{ x_{1}} \dot{ x_{2}} \cos{\left(\theta \right)} + \dot{ x_{2}}^{2}\right)}{2}$
# Euler-Lagrange equations:
# Coordinate 0:
# $\displaystyle \ddot{ x_{1}} \left(M + m\right) + \ddot{ x_{2}} m \cos{\left(\theta \right)} = 0$
# Coordinate 1:
# $\displaystyle m \left(\ddot{ x_{1}} \cos{\left(\theta \right)} + \ddot{ x_{2}} - g \sin{\left(\theta \right)}\right) = 0$
# Accelerations:
# Coordinate 0:
# $\displaystyle \ddot{ x_{1}} = \frac{g m \sin{\left(\theta \right)} \cos{\left(\theta \right)}}{- M + m \cos^{2}{\left(\theta \right)} - m}$
# Coordinate 1:
# $\displaystyle \ddot{ x_{2}} = - \frac{M g \sin{\left(\theta \right)}}{- M + m \cos^{2}{\left(\theta \right)} - m} - \frac{g m \sin{\left(\theta \right)}}{- M + m \cos^{2}{\left(\theta \right)} - m}$
# Hamiltonian for Example 1:
# $\displaystyle \mathcal{H} = \frac{- M g m^{2} x_{2} \sin{\left(\theta \right)} + \frac{M p_{x_{2}}^{2}}{2} - g m^{3} x_{2} \sin^{3}{\left(\theta \right)} + \frac{m p_{x_{1}}^{2}}{2} - m p_{x_{1}} p_{x_{2}} \cos{\left(\theta \right)} + \frac{m p_{x_{2}}^{2}}{2}}{m \left(M + m \sin^{2}{\left(\theta \right)}\right)}$
# Hamiltonian equations:
# Coordinate 0:
# $\displaystyle \dot{p_{x_{1}}} = 0,~~~~\dot{x_{1}} = \frac{m p_{x_{1}} - m p_{x_{2}} \cos{\left(\theta \right)}}{m \left(M + m \sin^{2}{\left(\theta \right)}\right)}$
# Coordinate 1:
# $\displaystyle \dot{p_{x_{2}}} = - \frac{- M g m^{2} \sin{\left(\theta \right)} - g m^{3} \sin^{3}{\left(\theta \right)}}{m \left(M + m \sin^{2}{\left(\theta \right)}\right)},~~~~\dot{x_{2}} = \frac{M p_{x_{2}} - m p_{x_{1}} \cos{\left(\theta \right)} + m p_{x_{2}}}{m \left(M + m \sin^{2}{\left(\theta \right)}\right)}$

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def Example_2(x, theta, dx, dtheta):
    M = sympy.Symbol('M')
    m = sympy.Symbol('m')
    g = sympy.Symbol('g')
    r = sympy.Symbol('r')
    half = sympy.Rational(1,2)
    T = half*M*dx**2 + half*m*(dx**2 + (r**2)*dtheta**2 + 2*dx*r*dtheta*sympy.cos(theta))
    U = -m*g*r*sympy.cos(theta)
    return T-U


solver2 = lagrangian.solver(n=2, lagrangian=Example_2, custom_coords=[r'x', r'\theta'])
equations2 = solver2.euler_lagrange_equations()
accelarations = solver2.get_second_derivatives(simplify=True)
p_eqs2, q_eqs2 = solver2.hamitonian_equations()

solver2.print_lagrangian()
print('Euler-Lagrange equations:')
for i in range(len(equations2)):
    print(f'Coordinate {i}:')
    lagrangian.pprint(equations2[i])
print('Accelerations:')
for i in range(len(accelarations)):
    print(f'Coordinate {i}:')
    lagrangian.pprint(accelarations[i])

print('\n')

solver2.print_hamiltonian()
print('Hamiltonian equations:')
for i in range(len(p_eqs2)):
    print(f'Coordinate {i}:')
    lagrangian.pprint(p_eqs2[i] + ',~~~~' + q_eqs2[i])
# Out:
# Lagrangian for Example 2:
# $\displaystyle \mathcal{L} = \frac{M \dot{ x}^{2}}{2} + g m r \cos{\left(\theta \right)} + \frac{m \left(\dot{ \theta}^{2} r^{2} + 2 \dot{ \theta} \dot{ x} r \cos{\left(\theta \right)} + \dot{ x}^{2}\right)}{2}$
# Euler-Lagrange equations:
# Coordinate 0:
# $\displaystyle \ddot{ \theta} m r \cos{\left(\theta \right)} + \ddot{ x} \left(M + m\right) - \dot{ \theta}^{2} m r \sin{\left(\theta \right)} = 0$
# Coordinate 1:
# $\displaystyle m r \left(\ddot{ \theta} r + \ddot{ x} \cos{\left(\theta \right)} + g \sin{\left(\theta \right)}\right) = 0$
# Accelerations:
# Coordinate 0:
# $\displaystyle \ddot{ x} = \frac{m \left(\dot{ \theta}^{2} r + g \cos{\left(\theta \right)}\right) \sin{\left(\theta \right)}}{M + m \sin^{2}{\left(\theta \right)}}$
# Coordinate 1:
# $\displaystyle \ddot{ \theta} = - \frac{\left(M g + \dot{ \theta}^{2} m r \cos{\left(\theta \right)} + g m\right) \sin{\left(\theta \right)}}{r \left(M + m \sin^{2}{\left(\theta \right)}\right)}$
# Hamiltonian for Example 2:
# $\displaystyle \mathcal{H} = \frac{- M g m^{2} r^{3} \cos{\left(\theta \right)} + \frac{M p_{\theta}^{2}}{2} - g m^{3} r^{3} \sin^{2}{\left(\theta \right)} \cos{\left(\theta \right)} + \frac{m p_{\theta}^{2}}{2} - m p_{\theta} p_{x} r \cos{\left(\theta \right)} + \frac{m p_{x}^{2} r^{2}}{2}}{m r^{2} \left(M + m \sin^{2}{\left(\theta \right)}\right)}$
# Hamiltonian equations:
# Coordinate 0:
# $\displaystyle \dot{p_{x}} = 0,~~~~\dot{x} = \frac{- m p_{\theta} r \cos{\left(\theta \right)} + m p_{x} r^{2}}{m r^{2} \left(M + m \sin^{2}{\left(\theta \right)}\right)}$
# Coordinate 1:
# $\displaystyle \dot{p_{\theta}} = \frac{2 \left(- M g m^{2} r^{3} \cos{\left(\theta \right)} + \frac{M p_{\theta}^{2}}{2} - g m^{3} r^{3} \sin^{2}{\left(\theta \right)} \cos{\left(\theta \right)} + \frac{m p_{\theta}^{2}}{2} - m p_{\theta} p_{x} r \cos{\left(\theta \right)} + \frac{m p_{x}^{2} r^{2}}{2}\right) \sin{\left(\theta \right)} \cos{\left(\theta \right)}}{r^{2} \left(M + m \sin^{2}{\left(\theta \right)}\right)^{2}} - \frac{M g m^{2} r^{3} \sin{\left(\theta \right)} + g m^{3} r^{3} \sin^{3}{\left(\theta \right)} - 2 g m^{3} r^{3} \sin{\left(\theta \right)} \cos^{2}{\left(\theta \right)} + m p_{\theta} p_{x} r \sin{\left(\theta \right)}}{m r^{2} \left(M + m \sin^{2}{\left(\theta \right)}\right)},~~~~\dot{\theta} = \frac{M p_{\theta} + m p_{\theta} - m p_{x} r \cos{\left(\theta \right)}}{m r^{2} \left(M + m \sin^{2}{\left(\theta \right)}\right)}$
